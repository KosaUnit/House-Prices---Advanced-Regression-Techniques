# %% [markdown]
# Course of action:
# 1. understand the problem
# 2. focus on dependency between independent and dependent(price) variable
# 3. clean data set (missing data, outliers, categorical variables)
# 4. check if out data meet requirements for multiple variable models

# %%
# look for missing data 
# look for outliers 

# use pantilization 
# use normalization (when to use it ?) 

# we have limited amount of data so we have to base of feature engineering +

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import norm # what is that ?
from sklearn.preprocessing import StandardScaler # what is that ?
from scipy import stats # what is that ?
import warnings # what is that ?
warnings.filterwarnings('ignore') # what is that ?

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# %matplotlib inline

# %%
df_train = pd.read_csv(r"C:\Users\48694\Desktop\Kaggle\House Prices - Advanced Regression Techniques\data\train.csv")

# %%
# df_train.info()

# %%
# df_train.columns[df_train.isnull().any()]

# %%
pd.read_excel('Sale House Project.xlsx', engine='openpyxl')
# Out:
#          Variable         Type Segment [building, space. location]  \
# 0              Id    numerical                                 NaN
# 1      MSSubClass    numerical                             bulding
# 2        MSZoning  cetegorical                            location
# 3     LotFrontage    numerical                               space
# 4         LotArea    numerical                               space
# 5          Street  cetegorical                               space
# 6           Alley  cetegorical                               space
# 7        LotShape  cetegorical                               space
# 8     LandContour  cetegorical                               space
# 9       Utilities  cetegorical                               space
# 10      LotConfig  cetegorical                            location
# 11      LandSlope  cetegorical                               space
# 12   Neighborhood  cetegorical                            location
# 13     Condition1  cetegorical                            location
# 14     Condition2  cetegorical                            location
# 15       BldgType  cetegorical                             bulding
# 16     HouseStyle  cetegorical                             bulding
# 17    OverallQual    numerical                             bulding
# 18    OverallCond    numerical                             bulding
# 19      YearBuilt    numerical                             bulding
# 20   YearRemodAdd    numerical                             bulding
# 21      RoofStyle  cetegorical                             bulding
# 22       RoofMatl  cetegorical                             bulding
# 23    Exterior1st  cetegorical                             bulding
# 24    Exterior2nd  cetegorical                             bulding
# 25     MasVnrType  cetegorical                             bulding
# 26     MasVnrArea    numerical                             bulding
# 27      ExterQual  cetegorical                             bulding
# 28      ExterCond  cetegorical                             bulding
# 29     Foundation  cetegorical                             bulding
# 30       BsmtQual  cetegorical                             bulding
# 31       BsmtCond  cetegorical                             bulding
# 32   BsmtExposure  cetegorical                             bulding
# 33   BsmtFinType1  cetegorical                             bulding
# 34     BsmtFinSF1    numerical                             bulding
# 35   BsmtFinType2  cetegorical                             bulding
# 36     BsmtFinSF2    numerical                             bulding
# 37      BsmtUnfSF    numerical                             bulding
# 38    TotalBsmtSF    numerical                             bulding
# 39        Heating  cetegorical                             bulding
# 40      HeatingQC  cetegorical                             bulding
# 41     CentralAir  cetegorical                             bulding
# 42     Electrical  cetegorical                             bulding
# 43       1stFlrSF    numerical                             bulding
# 44       2ndFlrSF    numerical                             bulding
# 45   LowQualFinSF    numerical                             bulding
# 46      GrLivArea    numerical                             bulding
# 47   BsmtFullBath    numerical                             bulding
# 48   BsmtHalfBath    numerical                             bulding
# 49       FullBath    numerical                             bulding
# 50       HalfBath    numerical                             bulding
# 51   BedroomAbvGr    numerical                             bulding
# 52   KitchenAbvGr    numerical                             bulding
# 53    KitchenQual  cetegorical                             bulding
# 54   TotRmsAbvGrd    numerical                             bulding
# 55     Functional  cetegorical                             bulding
# 56     Fireplaces    numerical                             bulding
# 57    FireplaceQu  cetegorical                             bulding
# 58     GarageType  cetegorical                             bulding
# 59    GarageYrBlt    numerical                             bulding
# 60   GarageFinish  cetegorical                             bulding
# 61     GarageCars    numerical                             bulding
# 62     GarageArea    numerical                             bulding
# 63     GarageQual  cetegorical                             bulding
# 64     GarageCond  cetegorical                             bulding
# 65     PavedDrive  cetegorical                             bulding
# 66     WoodDeckSF    numerical                             bulding
# 67    OpenPorchSF    numerical                             bulding
# 68  EnclosedPorch    numerical                             bulding
# 69      3SsnPorch    numerical                             bulding
# 70    ScreenPorch    numerical                             bulding
# 71       PoolArea    numerical                               space
# 72         PoolQC  cetegorical                               space
# 73          Fence  cetegorical                               space
# 74    MiscFeature  cetegorical                             bulding
# 75        MiscVal    numerical                                 NaN
# 76         MoSold    numerical                                 NaN
# 77         YrSold    numerical                                 NaN
# 78       SaleType  cetegorical                                 NaN
# 79  SaleCondition  cetegorical                                 NaN
# 80      SalePrice    numerical                                 NaN
#
#    Variable Value Expectation  Conclusions          Comments  Missing value
# 0                         NaN          NaN               NaN            NaN
# 1                        High          NaN  Type of building            NaN
# 2                        High          NaN      Type of zone            NaN
# 3                      Medium          NaN               NaN            1.0
# 4                        High          NaN               NaN            NaN
# 5                      Medium          NaN               NaN            NaN
# 6                        High          NaN               NaN            1.0
# 7                         Low          NaN               NaN            NaN
# 8                        High          NaN               NaN            NaN
# 9                        High          NaN               NaN            NaN
# 10                       High          NaN               NaN            NaN
# 11                       High          NaN               NaN            NaN
# 12                       High          NaN               NaN            NaN
# 13                       High          NaN               NaN            NaN
# 14                       High          NaN               NaN            NaN
# 15                       High          NaN               NaN            NaN
# 16                       High          NaN               NaN            NaN
# 17                       High          NaN               NaN            NaN
# 18                       High          NaN               NaN            NaN
# 19                        Low          NaN               NaN            NaN
# 20                        Low          NaN               NaN            NaN
# 21                        Low          NaN               NaN            NaN
# 22                     Medium          NaN               NaN            NaN
# 23                       High          NaN               NaN            NaN
# 24                       High          NaN               NaN            NaN
# 25                     Medium          NaN               NaN            1.0
# 26                     Medium          NaN               NaN            1.0
# 27                       High          NaN               NaN            NaN
# 28                       High          NaN               NaN            NaN
# 29                       High          NaN               NaN            NaN
# 30                     Medium          NaN               NaN            1.0
# 31                     Medium          NaN               NaN            1.0
# 32                       High          NaN               NaN            1.0
# 33                       High          NaN               NaN            1.0
# 34                        Low          NaN               NaN            NaN
# 35                        Low          NaN               NaN            1.0
# 36                        Low          NaN               NaN            NaN
# 37                       High          NaN               NaN            NaN
# 38                     Medium          NaN               NaN            NaN
# 39                       High          NaN               NaN            NaN
# 40                       High          NaN               NaN            NaN
# 41                       High          NaN               NaN            NaN
# 42                       High          NaN               NaN            1.0
# 43                       High          NaN               NaN            NaN
# 44                       High          NaN               NaN            NaN
# 45                       High          NaN               NaN            NaN
# 46                       High          NaN               NaN            NaN
# 47                        Low          NaN               NaN            NaN
# 48                        Low          NaN               NaN            NaN
# 49                       High          NaN               NaN            NaN
# 50                        Low          NaN               NaN            NaN
# 51                       High          NaN               NaN            NaN
# 52                        Low          NaN               NaN            NaN
# 53                       High          NaN               NaN            NaN
# 54                       High          NaN               NaN            NaN
# 55                     Medium          NaN               NaN            NaN
# 56                        Low          NaN               NaN            NaN
# 57                        Low          NaN               NaN            1.0
# 58                     Medium          NaN               NaN            1.0
# 59                        Low          NaN               NaN            1.0
# 60                     Medium          NaN               NaN            1.0
# 61                       High          NaN               NaN            NaN
# 62                     Medium          NaN               NaN            NaN
# 63                     Medium          NaN               NaN            1.0
# 64                     Medium          NaN               NaN            1.0
# 65                        Low          NaN               NaN            NaN
# 66                     Medium          NaN               NaN            NaN
# 67                     Medium          NaN               NaN            NaN
# 68                     Medium          NaN               NaN            NaN
# 69                     Medium          NaN               NaN            NaN
# 70                     Medium          NaN               NaN            NaN
# 71                     Medium          NaN               NaN            NaN
# 72                       High          NaN               NaN            1.0
# 73                     Medium          NaN               NaN            1.0
# 74                        Low          NaN               NaN            1.0
# 75                     Medium          NaN               NaN            NaN
# 76                        Low          NaN               NaN            NaN
# 77                       High          NaN               NaN            NaN
# 78                     Medium          NaN               NaN            NaN
# 79                       High          NaN               NaN            NaN
# 80                        NaN          NaN               NaN            NaN
