# %% [markdown]
# Course of action:
# 1. understand the problem
# 2. focus on dependency between independent and dependent(price) variable
# 3. clean data set (missing data, outliers, categorical variables)
# 4. check if out data meet requirements for multiple variable models

# %%
# look for missing data 
# look for outliers 

# use pantilization 
# use normalization (when to use it ?) 

# we have limited amount of data so we have to base of feature engineering +

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import norm # what is that ?
from sklearn.preprocessing import StandardScaler # what is that ?
from scipy import stats # what is that ?
import warnings # what is that ?
warnings.filterwarnings('ignore') # what is that ?

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# %matplotlib inline

# %%
df_train = pd.read_csv(r"C:\Users\48694\Desktop\Local GitHub\Kaggle\House Prices - Advanced Regression Techniques\data\train.csv")

# %% [markdown]
# # Handling missing values

# %% [markdown]
# ## 1. overview of missing values in data set

# %%
missing_summary = pd.DataFrame(
    {'Missing_values': df_train.isnull().sum(),
     'Percentage': df_train.isnull().sum()/len(df_train) * 100}
)

missing_summary[missing_summary['Percentage'] > 0]
# Out:
#               Missing_values  Percentage
# LotFrontage              259   17.739726
# Alley                   1369   93.767123
# MasVnrType               872   59.726027
# MasVnrArea                 8    0.547945
# BsmtQual                  37    2.534247
# BsmtCond                  37    2.534247
# BsmtExposure              38    2.602740
# BsmtFinType1              37    2.534247
# BsmtFinType2              38    2.602740
# Electrical                 1    0.068493
# FireplaceQu              690   47.260274
# GarageType                81    5.547945
# GarageYrBlt               81    5.547945
# GarageFinish              81    5.547945
# GarageQual                81    5.547945
# GarageCond                81    5.547945
# PoolQC                  1453   99.520548
# Fence                   1179   80.753425
# MiscFeature             1406   96.301370

# %% [markdown]
# ### Examin the missing values and consider what to do with them
#
# Over 45% of missing values:
#
# - Alley (high) - 93% - not enough data, kind of overlaping info with "Street" but they are different, to many losing once, droped
# - MasVnrType (Masonry veneer type - Medium) - 60% not imporant
# - FireplaceQu (low) - 47% - when there is 0 fireplaces it is by default set to NA, update it to "NoFireplace" and only for valyes where fire amounts equal to 0
# - PoolQC (High) - 99% - when the pool area is zero set PoolQC to NoPool
# - Fence (medium) - 91% - not enaught data, dropped
# - MiscFeature (low) - 96% - mostly sheed or no shed, so I can change a name of a column to sheed, and change it to true and false.
#
# Below 20% of missing values:
# - LotFrontage (Linear feet of street connected to property) - 17%
# - MasVnrArea
# - BsmtQual
# - BsmtCond
# - BsmtExposure
# - BsmtFinType1
# - BsmtFinType2
# - Electrical

# %%
df_train['shed'] = np.where(df_train['MiscFeature'] == 'Shed', 'Y', 'N')
df_train.loc[df_train['Fireplaces'] == 0, 'FireplaceQu'] = 'NoFireplace'
df_train.loc[df_train['PoolArea'] == 0, 'PoolQC'] = 'NoPool'
df_train = df_train.drop(columns=['MiscFeature', 'Alley', 'MasVnrType', 'Fence'])

# %%
# df_train.head(15)
df_train['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df_train['PoolQC'].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
# df_train[['FireplaceQu', 'Fireplaces']]

df_train['PoolQC'].isnull().any()
# Out:
# np.False_

# %%
df_train[['PoolQC', 'PoolArea']]
# Out:
#      PoolQC  PoolArea
# 0       NaN         0
# 1       NaN         0
# 2       NaN         0
# 3       NaN         0
# 4       NaN         0
# 5       NaN         0
# 6       NaN         0
# 7       NaN         0
# 8       NaN         0
# 9       NaN         0
# 10      NaN         0
# 11      NaN         0
# 12      NaN         0
# 13      NaN         0
# 14      NaN         0
# 15      NaN         0
# 16      NaN         0
# 17      NaN         0
# 18      NaN         0
# 19      NaN         0
# 20      NaN         0
# 21      NaN         0
# 22      NaN         0
# 23      NaN         0
# 24      NaN         0
# 25      NaN         0
# 26      NaN         0
# 27      NaN         0
# 28      NaN         0
# 29      NaN         0
# 30      NaN         0
# 31      NaN         0
# 32      NaN         0
# 33      NaN         0
# 34      NaN         0
# 35      NaN         0
# 36      NaN         0
# 37      NaN         0
# 38      NaN         0
# 39      NaN         0
# ...
